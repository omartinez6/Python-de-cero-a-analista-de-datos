# %%
import calplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import calplot
#
# ModuleNotFoundError: No module named 'calplot'

# %%
calplot.yearplot?
# Out:
# Object `calplot.yearplot` not found.
